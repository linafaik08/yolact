# %%
import pandas as pd
import json
from PIL import Image
import os

# %%
PATH_IMG = "/kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/images"
PATH_MASK = "/kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks"

# %%
category_map = {'crack': '(255, 255, 255)'}

# %%
# Source code:
# https://github.com/chrise96/image-to-coco-json-converter/blob/master/src/create_annotations.py

from PIL import Image
import numpy as np
from skimage import measure
from shapely.geometry import Polygon, MultiPolygon
import os
import json
import pandas as pd

def create_sub_masks(mask_image, width, height):
    # Initialize a dictionary of sub-masks indexed by RGB colors

    sub_masks = {}
    for x in range(width):
        for y in range(height):
            # Get the RGB values of the pixel
            pixel = mask_image.getpixel((x,y))[:3]

            # Check to see if we have created a sub-mask...
            pixel_str = str(pixel)
            sub_mask = sub_masks.get(pixel_str)
            if sub_mask is None:
               # Create a sub-mask (one bit per pixel) and add to the dictionary
                # Note: we add 1 pixel of padding in each direction
                # because the contours module doesn"t handle cases
                # where pixels bleed to the edge of the image

                sub_masks[pixel_str] = Image.new("1", (width+2, height+2))

            # Set the pixel value to 1 (default is 0), accounting for padding
            sub_masks[pixel_str].putpixel((x+1, y+1), 1)

    return sub_masks

def create_sub_mask_annotation(sub_mask, tol, threshold_area):
    # Find contours (boundary lines) around each sub-mask
    # Note: there could be multiple contours if the object
    # is partially occluded. (E.g. an elephant behind a tree)
    contours = measure.find_contours(np.array(sub_mask), 0.5, positive_orientation="low")

    polygons = []
    segmentations = []
    for contour in contours:
        # Flip from (row, col) representation to (x, y)
        # and subtract the padding pixel
        for i in range(len(contour)):
            row, col = contour[i]
            contour[i] = (col - 1, row - 1)

        # Make a polygon and simplify it
        poly = Polygon(contour)

        poly = poly.simplify(tol, preserve_topology=True)

        if(poly.is_empty) or poly.area<threshold_area:
            # Go to next iteration, dont save empty values in list
            continue

        polygons.append(poly)

        segmentation = np.array(poly.exterior.coords).ravel().tolist()
        segmentations.append(segmentation)

    return polygons, segmentations

def create_category_annotation(category_dict):
    category_list = []

    for key, value in category_dict.items():
        category = {
            "supercategory": key,
            "id": value,
            "name": key
        }
        category_list.append(category)

    return category_list

def create_image_annotation(file_name, width, height, image_id):
    images = {
        "file_name": file_name,
        "height": height,
        "width": width,
        "id": image_id
    }

    return images

def create_annotation_format(polygon, segmentation, image_id, category_id, annotation_id):
    min_x, min_y, max_x, max_y = polygon.bounds
    width = max_x - min_x
    height = max_y - min_y
    bbox = (min_x, min_y, width, height)
    area = polygon.area

    annotation = {
        "segmentation": segmentation,
        "area": area,
        "iscrowd": 0,
        "image_id": image_id,
        "bbox": bbox,
        "category_id": category_id,
        "id": annotation_id
    }

    return annotation

def get_coco_json_format():
    # Standard COCO format
    coco_format = {
        "info": {},
        "licenses": [],
        "images": [{}],
        "categories": [{}],
        "annotations": [{}]
    }

    return coco_format

def images_annotations_info(paths_df, category_colors, multipolygon_ids, n_images_max=None, tol=100, threshold_area = 10):
    annotation_id = 0
    annotations = []
    images = []
    
    n_images = paths_df.shape[0]

    for image_id in range(n_images):
        line = paths_df.iloc[image_id]
        
        print('image {}/{}'.format(image_id+1, n_images))

        mask_image_open = Image.open(line.path_mask).convert("RGB")
        print(line.path_mask)
        
        w, h = mask_image_open.size

        # "images" info
        image = create_image_annotation(line.path_image, w, h, image_id)
        images.append(image)
        
        sub_masks = create_sub_masks(mask_image_open, w, h)

        for color, sub_mask in sub_masks.items():

            if color in category_colors.keys():

                category_id = category_colors[color]

                # "annotations" info
                polygons, segmentations = create_sub_mask_annotation(sub_mask,  tol, threshold_area)
                
                #return sub_masks, polygons, segmentations

                # Check if we have classes that are a multipolygon
                if category_id in multipolygon_ids:
                    
                    # Combine the polygons to calculate the bounding box and area
                    multi_poly = MultiPolygon(polygons)

                    annotation = create_annotation_format(multi_poly, segmentations, image_id, category_id, annotation_id)

                    annotations.append(annotation)
                    annotation_id += 1
                
        image_id += 1

        if n_images_max is not None and n_images_max<=image_id:
            break
    
    return images, annotations, annotation_id

# %%
category_ids = {cat: i+1 for i,cat in enumerate(category_map.keys())}
category_colors = {color: i+1 for i,color in enumerate(category_map.values())}
multipolygon_ids = list(category_ids.values())

# %%
n_images_max = None # limit the number of images to process when debugging

# %%
files_imgs = [os.path.join(PATH_IMG, p) for p in os.listdir(PATH_IMG)]
files_masks = [os.path.join(PATH_MASK, p) for p in os.listdir(PATH_MASK)]

paths_df = pd.DataFrame(files_imgs, columns = ['path_image'])
paths_df['image'] = paths_df.path_image.apply(lambda x: x.split('/')[-1])

paths_m_df = pd.DataFrame(files_masks, columns = ['path_mask'])
paths_m_df['image'] = paths_m_df.path_mask.apply(lambda x: x.split('/')[-1])

paths_df = paths_df.merge(paths_m_df, on='image', how='inner')

# %%
paths_df.head()
# Out:
#                                           path_image  \
# 0  /kaggle/input/crack-segmentation-dataset/crack...
# 1  /kaggle/input/crack-segmentation-dataset/crack...
# 2  /kaggle/input/crack-segmentation-dataset/crack...
# 3  /kaggle/input/crack-segmentation-dataset/crack...
# 4  /kaggle/input/crack-segmentation-dataset/crack...
#
#                                                image  \
# 0                           DeepCrack_IMG_6469-7.jpg
# 1  Rissbilder_for_Florian_9S6A2828_80_1698_3421_3...
# 2  Rissbilder_for_Florian_9S6A2880_131_2019_3358_...
# 3                 CRACK500_20160222_164851_641_1.jpg
# 4              CRACK500_20160316_144203_1921_721.jpg
#
#                                            path_mask
# 0  /kaggle/input/crack-segmentation-dataset/crack...
# 1  /kaggle/input/crack-segmentation-dataset/crack...
# 2  /kaggle/input/crack-segmentation-dataset/crack...
# 3  /kaggle/input/crack-segmentation-dataset/crack...
# 4  /kaggle/input/crack-segmentation-dataset/crack...

# %%
coco_format = get_coco_json_format()
coco_format["categories"] = create_category_annotation(category_ids)
coco_format["images"], coco_format["annotations"], annotation_cnt = images_annotations_info(
    paths_df, category_colors, multipolygon_ids, n_images_max, threshold_area=0.2)
# Out:
# image 1/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_IMG_6469-7.jpg
# image 2/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2828_80_1698_3421_3098.jpg
# image 3/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2880_131_2019_3358_3435.jpg
# image 4/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160222_164851_641_1.jpg
# image 5/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160316_144203_1921_721.jpg
# image 6/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2901_866_955_2850_3013.jpg
# image 7/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_071.jpg
# image 8/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160316_142226_641_361.jpg
# image 9/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2852_43_22_4553_3770.jpg
# image 10/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2919_1238_88_3664_3499.jpg
# image 11/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3100_62_648_2874_2646.jpg
# image 12/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2785_197_1269_2404_2359.jpg
# image 13/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/cracktree200_6723.jpg
# image 14/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3088_0_0_3840_5760.jpg
# image 15/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160307_144842_641_1.jpg
# image 16/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160222_164000_1281_361.jpg
# image 17/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_54_12.jpg.jpg
# image 18/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153544_1_721.jpg
# image 19/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_34_6.jpg.jpg
# image 20/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160303_093353_1281_361.jpg
# image 21/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_79_1.jpg.jpg
# image 22/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/forest_092.jpg
# image 23/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160316_141721_1921_361.jpg
# image 24/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160321_183951_1921_361.jpg
# image 25/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2837_158_672_3496_4093.jpg
# image 26/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2867_0_0_3840_5760.jpg
# image 27/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01641_600_4_1717_1816.jpg
# image 28/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_IMG25-6.jpg
# image 29/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2848_105_342_3183_3261.jpg
# image 30/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2875_186_162_2416_1888.jpg
# image 31/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2814_122_2129_2898_2972.jpg
# image 32/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01631_7_759_1715_1841.jpg
# image 33/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_83_8.jpg.jpg
# image 34/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2905_212_578_2350_1884.jpg
# image 35/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3115_510_56_3501_2630.jpg
# image 36/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_24_10.jpg.jpg
# image 37/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_43_47.jpg.jpg
# image 38/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_151241_1_361.jpg
# image 39/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160402_150314_1_721.jpg
# image 40/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2806_0_0_5760_3840.jpg
# image 41/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3124_428_1773_3196_2604.jpg
# image 42/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2866_277_585_3310_3706.jpg
# image 43/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160306_104522_1281_721.jpg
# image 44/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2785_10_2229_3816_3345.jpg
# image 45/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2905_1082_994_2878_2819.jpg
# image 46/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_98_3.jpg.jpg
# image 47/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2799_544_1031_2642_3048.jpg
# image 48/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_151013_361_1921.jpg
# image 49/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160310_114658_641_361.jpg
# image 50/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Eugen_Muller_4470_0_0_1054_1067.jpg
# image 51/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_76_37.jpg.jpg
# image 52/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01645_0_0_2736_1824.jpg
# image 53/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_150927_1_721.jpg
# image 54/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2885_67_973_3621_3313.jpg
# image 55/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2793_1267_233_2859_3346.jpg
# image 56/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_32_7.jpg.jpg
# image 57/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3110_557_1927_2661_2252.jpg
# image 58/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0692_1_641.jpg
# image 59/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2812_6_41_3627_3234.jpg
# image 60/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2812_207_266_3436_3565.jpg
# image 61/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_61_12.jpg.jpg
# image 62/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153848_1_1.jpg
# image 63/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2905_452_32_2418_2064.jpg
# image 64/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2889_742_81_2412_2438.jpg
# image 65/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160407_163522_1_361.jpg
# image 66/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_45_15.jpg.jpg
# image 67/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2817_1306_744_2501_3137.jpg
# image 68/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_58_8.jpg.jpg
# image 69/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2859_1580_320_3896_3471.jpg
# image 70/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2886_6_1555_2728_3462.jpg
# image 71/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01625_77_14_1502_1897.jpg
# image 72/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0690_541_1.jpg
# image 73/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01626_757_1195_1027_1063.jpg
# image 74/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_55_49.jpg.jpg
# image 75/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2845_319_713_2808_3088.jpg
# image 76/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2813_33_921_3707_3074.jpg
# image 77/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3113_121_515_3381_3799.jpg
# image 78/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153813_1281_1081.jpg
# image 79/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2803_612_408_2717_3030.jpg
# image 80/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2904_124_1078_2840_3201.jpg
# image 81/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160225_114535_1_1.jpg
# image 82/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_104205_1_721.jpg
# image 83/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153632_641_1.jpg
# image 84/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_094003_641_721.jpg
# image 85/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2877_458_1207_3052_3365.jpg
# image 86/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160307_144842_1281_721.jpg
# image 87/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/cracktree200_6291.jpg
# image 88/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160326_174634_1921_361.jpg
# image 89/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11184.jpg
# image 90/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160330_165325_641_721.jpg
# image 91/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_76_27.jpg.jpg
# image 92/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01670_528_1159_1273_1257.jpg
# image 93/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2865_3_933_3759_4166.jpg
# image 94/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01643_0_0_2736_1824.jpg
# image 95/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2793_2047_533_3461_3029.jpg
# image 96/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160405_171219_1_721.jpg
# image 97/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3098_31_1058_3800_4556.jpg
# image 98/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_20_66.jpg.jpg
# image 99/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01685_252_569_1566_2047.jpg
# image 100/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_24_7.jpg.jpg
# image 101/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153657_1_361.jpg
# image 102/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2784_54_926_3721_4414.jpg
# image 103/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_154454_641_361.jpg
# image 104/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2874_212_650_3441_2826.jpg
# image 105/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_016.jpg
# image 106/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3124_83_2234_3141_2608.jpg
# image 107/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_Im_GT_ESAR_27a.jpg
# image 108/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2850_1292_135_4332_3513.jpg
# image 109/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_101_11.jpg.jpg
# image 110/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_094507_1921_721.jpg
# image 111/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2874_1058_2264_2666_2239.jpg
# image 112/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_1085_541_1.jpg
# image 113/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160306_104456_641_361.jpg
# image 114/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_IMG_2933_1297_485.jpg
# image 115/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11249-6.jpg
# image 116/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/cracktree200_6677.jpg
# image 117/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01671_598_987_1196_1561.jpg
# image 118/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_101347_1_361.jpg
# image 119/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160321_185637_1281_721.jpg
# image 120/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01631_0_0_1824_2736.jpg
# image 121/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2835_503_2588_3064_2686.jpg
# image 122/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2912_181_766_3589_4546.jpg
# image 123/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3115_1205_28_4097_3781.jpg
# image 124/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/cracktree200_6284.jpg
# image 125/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_14_4.jpg.jpg
# image 126/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160307_162438_1_361.jpg
# image 127/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_151402_1_721.jpg
# image 128/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_154352_1281_361.jpg
# image 129/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2811_0_0_5760_3840.jpg
# image 130/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_IMG_6537-5.jpg
# image 131/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2849_151_1163_3684_4272.jpg
# image 132/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2826_1048_2494_2739_2977.jpg
# image 133/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_151402_1281_721.jpg
# image 134/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2853_2209_406_3309_3401.jpg
# image 135/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2876_297_1693_3135_3358.jpg
# image 136/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_70_1.jpg.jpg
# image 137/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3093_434_1169_2203_2493.jpg
# image 138/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0581_541_1.jpg
# image 139/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160330_170014_1_721.jpg
# image 140/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01669_216_632_1558_1754.jpg
# image 141/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01684_0_0_1824_2736.jpg
# image 142/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3134_856_207_2810_3507.jpg
# image 143/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01658_386_50_1409_1140.jpg
# image 144/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2818_22_73_3648_4328.jpg
# image 145/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01697_920_29_1585_1783.jpg
# image 146/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_009.jpg
# image 147/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2796_21_296_3652_3809.jpg
# image 148/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2787_1034_2113_2702_3383.jpg
# image 149/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_24_18.jpg.jpg
# image 150/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/cracktree200_6753.jpg
# image 151/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_38_1.jpg.jpg
# image 152/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2795_470_301_3316_2734.jpg
# image 153/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2911_309_172_2267_2920.jpg
# image 154/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/cracktree200_6718.jpg
# image 155/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3117_308_954_3386_3746.jpg
# image 156/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160310_114418_641_1.jpg
# image 157/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153845_1_1.jpg
# image 158/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_102_0.jpg.jpg
# image 159/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01672_39_1294_1098_1354.jpg
# image 160/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CFD_040.jpg
# image 161/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160330_164935_1281_1081.jpg
# image 162/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160407_165001_641_721.jpg
# image 163/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_073245_641_721.jpg
# image 164/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_1304_541_1.jpg
# image 165/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2903_390_534_3068_3071.jpg
# image 166/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_52_0.jpg.jpg
# image 167/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_073736_1921_361.jpg
# image 168/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01664_5_648_1787_1401.jpg
# image 169/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3136_674_13_4483_3701.jpg
# image 170/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/forest_100.jpg
# image 171/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01637_25_1102_1528_1598.jpg
# image 172/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2846_230_168_2768_2605.jpg
# image 173/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_152022_1_721.jpg
# image 174/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2875_1394_1999_2364_3031.jpg
# image 175/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0776_1_1.jpg
# image 176/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01651_61_82_1347_1168.jpg
# image 177/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_053.jpg
# image 178/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/cracktree200_6310.jpg
# image 179/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CFD_029.jpg
# image 180/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3094_596_1754_2681_3046.jpg
# image 181/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153612_1281_1081.jpg
# image 182/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2815_585_114_4389_3377.jpg
# image 183/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3108_68_1202_3372_3857.jpg
# image 184/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3124_393_930_3214_3138.jpg
# image 185/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160306_103613_1921_361.jpg
# image 186/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11134-2.jpg
# image 187/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2911_622_1439_2207_2876.jpg
# image 188/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_072824_641_361.jpg
# image 189/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_154321_641_361.jpg
# image 190/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2852_1479_510_3289_2569.jpg
# image 191/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_3_1.jpg.jpg
# image 192/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160402_150938_1281_1081.jpg
# image 193/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01708_146_565_1550_1877.jpg
# image 194/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_20_61.jpg.jpg
# image 195/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01693_0_0_2736_1824.jpg
# image 196/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01653_120_360_1526_1294.jpg
# image 197/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160405_171723_1_721.jpg
# image 198/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01675_3_938_1807_1587.jpg
# image 199/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_91_2.jpg.jpg
# image 200/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0556_541_1.jpg
# image 201/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2902_0_0_3840_5760.jpg
# image 202/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160222_165909_1_361.jpg
# image 203/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_61_4.jpg.jpg
# image 204/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_094632_641_721.jpg
# image 205/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_15_1.jpg.jpg
# image 206/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01705_680_705_1083_950.jpg
# image 207/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11192-2.jpg
# image 208/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2799_365_2829_2789_2815.jpg
# image 209/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0686_541_1.jpg
# image 210/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01662_196_599_1454_1898.jpg
# image 211/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_66_8.jpg.jpg
# image 212/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2916_941_64_3706_3630.jpg
# image 213/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2791_161_125_3509_4207.jpg
# image 214/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160326_142403_1921_361.jpg
# image 215/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2835_637_235_2191_2778.jpg
# image 216/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_24_25.jpg.jpg
# image 217/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2889_680_1937_2320_2689.jpg
# image 218/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01670_145_166_1628_2024.jpg
# image 219/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_24_51.jpg.jpg
# image 220/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2847_204_628_2627_2674.jpg
# image 221/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_75_21.jpg.jpg
# image 222/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2847_561_567_3001_3816.jpg
# image 223/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2919_2002_227_3415_3544.jpg
# image 224/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01667_585_135_1011_1326.jpg
# image 225/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_104031_641_361.jpg
# image 226/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11301-5.jpg
# image 227/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01679_375_930_1239_1240.jpg
# image 228/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160306_104527_641_721.jpg
# image 229/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01705_221_527_1603_1965.jpg
# image 230/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2867_1282_2088_2198_2394.jpg
# image 231/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2859_2569_213_3099_2735.jpg
# image 232/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3088_614_715_2901_2603.jpg
# image 233/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3126_16_1475_3344_3255.jpg
# image 234/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3097_27_1299_2545_2475.jpg
# image 235/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2841_319_1106_2769_3450.jpg
# image 236/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11179-1.jpg
# image 237/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_Im_GT_ESAR_30a.jpg
# image 238/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_104107_1281_721.jpg
# image 239/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3122_370_1386_3208_3073.jpg
# image 240/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01686_73_59_1743_1782.jpg
# image 241/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0661_1_641.jpg
# image 242/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/forest_048.jpg
# image 243/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_41_44.jpg.jpg
# image 244/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2816_266_193_2995_2732.jpg
# image 245/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_1167_541_641.jpg
# image 246/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160306_103613_1_361.jpg
# image 247/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2825_593_3041_2623_2519.jpg
# image 248/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3102_375_2426_3300_2531.jpg
# image 249/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153732_1921_361.jpg
# image 250/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_151027_641_1081.jpg
# image 251/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_151657_641_721.jpg
# image 252/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2866_189_191_3530_2828.jpg
# image 253/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160402_150942_641_721.jpg
# image 254/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_154339_1_361.jpg
# image 255/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160316_143547_641_361.jpg
# image 256/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_34_5.jpg.jpg
# image 257/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2850_902_258_3965_3335.jpg
# image 258/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_54_32.jpg.jpg
# image 259/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/forest_008.jpg
# image 260/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2922_23_953_2196_2800.jpg
# image 261/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_326.jpg
# image 262/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3103_513_1787_2538_2641.jpg
# image 263/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_IMG33-7.jpg
# image 264/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160326_150337_1_361.jpg
# image 265/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3132_1395_2_3332_3766.jpg
# image 266/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_76_54.jpg.jpg
# image 267/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160405_172849_641_721.jpg
# image 268/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160407_163257_1921_721.jpg
# image 269/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153544_1281_361.jpg
# image 270/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_9_5.jpg.jpg
# image 271/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2865_127_1723_2744_2847.jpg
# image 272/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2808_30_709_3501_4305.jpg
# image 273/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2864_0_0_3840_5760.jpg
# image 274/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2843_1369_1422_2224_2176.jpg
# image 275/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2874_229_528_3347_4299.jpg
# image 276/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153620_641_721.jpg
# image 277/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_052.jpg
# image 278/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_24_36.jpg.jpg
# image 279/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_072831_641_1.jpg
# image 280/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0622_541_641.jpg
# image 281/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3128_7_578_2768_3056.jpg
# image 282/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2878_373_2066_2452_3245.jpg
# image 283/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_14_32.jpg.jpg
# image 284/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_075.jpg
# image 285/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_9_22.jpg.jpg
# image 286/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2827_1172_836_2226_2545.jpg
# image 287/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2897_275_1133_3532_3542.jpg
# image 288/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CFD_101.jpg
# image 289/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01649_372_990_1335_1743.jpg
# image 290/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2841_574_2226_3122_3442.jpg
# image 291/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3123_338_77_3410_2903.jpg
# image 292/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3128_54_2559_3419_2773.jpg
# image 293/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_41_24.jpg.jpg
# image 294/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_1347_541_641.jpg
# image 295/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160307_164226_1_1.jpg
# image 296/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_IMG_6472-5.jpg
# image 297/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01655_404_201_1898_1481.jpg
# image 298/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3136_285_231_2725_3295.jpg
# image 299/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160222_165218_1921_1081.jpg
# image 300/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160407_163257_1921_1081.jpg
# image 301/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0936_541_1.jpg
# image 302/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_95_7.jpg.jpg
# image 303/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160324_173501_1921_721.jpg
# image 304/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/cracktree200_6725.jpg
# image 305/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160326_150319_721_641.jpg
# image 306/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160307_163552_1281_721.jpg
# image 307/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01666_25_567_1789_1513.jpg
# image 308/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160405_171215_1_361.jpg
# image 309/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_151409_1921_721.jpg
# image 310/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160318_181632_1921_361.jpg
# image 311/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_IMG_2936_1945_485.jpg
# image 312/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_152511_1921_361.jpg
# image 313/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2906_731_794_2280_2741.jpg
# image 314/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160222_165256_1281_1.jpg
# image 315/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2901_89_1339_3746_3193.jpg
# image 316/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160330_163946_1921_361.jpg
# image 317/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2887_730_3405_2293_2207.jpg
# image 318/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2857_629_1586_2970_3807.jpg
# image 319/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_1381_1_1.jpg
# image 320/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_073014_1281_361.jpg
# image 321/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3123_240_2905_2709_2486.jpg
# image 322/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0423_1_1.jpg
# image 323/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_54_69.jpg.jpg
# image 324/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2836_1190_1389_2270_2353.jpg
# image 325/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_073356_641_1081.jpg
# image 326/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3092_419_511_2526_3255.jpg
# image 327/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160405_171431_1_721.jpg
# image 328/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_23_1.jpg.jpg
# image 329/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3087_633_115_3073_3932.jpg
# image 330/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3097_59_1530_3511_3750.jpg
# image 331/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160316_143603_1281_361.jpg
# image 332/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_155737_1921_1081.jpg
# image 333/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3093_213_290_3581_4132.jpg
# image 334/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_Im_noGT_ESAR_25a.jpg
# image 335/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160316_143603_1921_361.jpg
# image 336/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_152328_1281_361.jpg
# image 337/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_074330_641_721.jpg
# image 338/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2877_129_312_2915_3093.jpg
# image 339/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01693_1323_467_1353_1116.jpg
# image 340/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3090_960_1737_2204_2039.jpg
# image 341/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_103609_721_1281.jpg
# image 342/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160222_165951_1281_721.jpg
# image 343/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_101524_641_721.jpg
# image 344/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_74_19.jpg.jpg
# image 345/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11190-3.jpg
# image 346/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2818_379_1117_3094_3636.jpg
# image 347/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_IMG_2942_1945_485.jpg
# image 348/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2825_973_1696_2431_3073.jpg
# image 349/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3090_393_349_2718_3325.jpg
# image 350/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2896_298_1569_3512_3276.jpg
# image 351/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_43_5.jpg.jpg
# image 352/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_104107_1921_361.jpg
# image 353/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_7Q3A9064-9.jpg
# image 354/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/cracktree200_6717.jpg
# image 355/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01671_213_937_1406_1469.jpg
# image 356/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160321_185534_641_361.jpg
# image 357/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_094507_641_721.jpg
# image 358/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01637_19_748_1394_1408.jpg
# image 359/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3102_384_651_3184_3117.jpg
# image 360/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2806_1282_666_3500_3093.jpg
# image 361/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2874_260_1101_3564_4657.jpg
# image 362/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0593_1_1.jpg
# image 363/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160222_115828_641_1.jpg
# image 364/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11170.jpg
# image 365/11298
# ...
# image 11181/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2901_134_2094_3674_3462.jpg
# image 11182/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_IMG_6542-4.jpg
# image 11183/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_54_68.jpg.jpg
# image 11184/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_100_5.jpg.jpg
# image 11185/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11248-1.jpg
# image 11186/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_IMG_6544-3.jpg
# image 11187/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_Im_GT_ESAR_32a.jpg
# image 11188/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_19_7.jpg.jpg
# image 11189/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0544_1_1.jpg
# image 11190/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2922_206_133_3609_2716.jpg
# image 11191/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160316_143445_1281_721.jpg
# image 11192/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01627_1186_456_1252_1118.jpg
# image 11193/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2865_358_52_2291_2044.jpg
# image 11194/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_83_3.jpg.jpg
# image 11195/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Sylvie_Chambon_318.jpg
# image 11196/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_IMG_2938_1297_969.jpg
# image 11197/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2892_1353_65_2769_3664.jpg
# image 11198/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_97_4.jpg.jpg
# image 11199/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3091_310_338_2855_2405.jpg
# image 11200/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160225_114503_641_361.jpg
# image 11201/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160316_142014_1281_361.jpg
# image 11202/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_54_56.jpg.jpg
# image 11203/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_59_3.jpg.jpg
# image 11204/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160330_160957_641_721.jpg
# image 11205/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01642_523_71_1616_1676.jpg
# image 11206/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3112_249_446_2971_2996.jpg
# image 11207/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_22_8.jpg.jpg
# image 11208/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_58_1.jpg.jpg
# image 11209/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01612_694_1203_1062_1156.jpg
# image 11210/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01660_195_872_1218_1421.jpg
# image 11211/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_97_0.jpg.jpg
# image 11212/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3119_660_1886_2702_2281.jpg
# image 11213/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160307_145259_1281_361.jpg
# image 11214/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_24_12.jpg.jpg
# image 11215/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2903_1569_1666_2006_2508.jpg
# image 11216/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_103626_641_361.jpg
# image 11217/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3138_304_1884_2471_2784.jpg
# image 11218/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_76_2.jpg.jpg
# image 11219/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3091_1038_3034_2641_2372.jpg
# image 11220/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_54_54.jpg.jpg
# image 11221/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2839_444_832_2780_2405.jpg
# image 11222/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_154540_1921_721.jpg
# image 11223/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3120_1339_2123_2283_2958.jpg
# image 11224/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3132_852_494_3394_3210.jpg
# image 11225/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2913_13_355_3631_4580.jpg
# image 11226/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_21_0.jpg.jpg
# image 11227/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_150821_1_361.jpg
# image 11228/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_61_16.jpg.jpg
# image 11229/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0959_1_641.jpg
# image 11230/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_101511_1921_1.jpg
# image 11231/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160405_172908_641_1.jpg
# image 11232/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0516_541_641.jpg
# image 11233/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_115531_1281_1081.jpg
# image 11234/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2900_531_2305_2740_3201.jpg
# image 11235/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3114_826_265_2930_3194.jpg
# image 11236/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160316_142539_641_721.jpg
# image 11237/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160321_185557_641_721.jpg
# image 11238/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160303_091825_1_1.jpg
# image 11239/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160307_164226_1281_361.jpg
# image 11240/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_094512_641_361.jpg
# image 11241/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2802_1473_189_3181_3391.jpg
# image 11242/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2790_0_1421_3645_3519.jpg
# image 11243/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2845_756_791_2427_2755.jpg
# image 11244/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160222_165937_641_361.jpg
# image 11245/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160330_170308_1921_721.jpg
# image 11246/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2828_364_378_3328_2718.jpg
# image 11247/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_151151_641_721.jpg
# image 11248/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2825_162_936_3635_4699.jpg
# image 11249/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01609_147_1332_1399_1227.jpg
# image 11250/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_1281_541_641.jpg
# image 11251/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2811_1375_255_3271_2730.jpg
# image 11252/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2866_843_69_2961_2669.jpg
# image 11253/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_072824_641_721.jpg
# image 11254/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_154017_1921_361.jpg
# image 11255/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160222_115233_1_361.jpg
# image 11256/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01685_440_355_1251_1007.jpg
# image 11257/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01686_270_206_1383_1524.jpg
# image 11258/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/DeepCrack_11301-6.jpg
# image 11259/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_82_2.jpg.jpg
# image 11260/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160329_094512_641_1.jpg
# image 11261/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Eugen_Muller_8980a_180_143_640_574.jpg
# image 11262/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CFD_118.jpg
# image 11263/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2918_122_197_3579_3238.jpg
# image 11264/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153540_1921_1.jpg
# image 11265/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_153918_1_361.jpg
# image 11266/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2889_336_716_2820_3215.jpg
# image 11267/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3085_67_497_3262_3700.jpg
# image 11268/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_152305_1921_361.jpg
# image 11269/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_154535_641_721.jpg
# image 11270/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2789_107_621_3554_4612.jpg
# image 11271/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2903_293_874_2538_3346.jpg
# image 11272/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0698_1_641.jpg
# image 11273/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160328_151423_1281_361.jpg
# image 11274/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2828_676_2395_2093_2578.jpg
# image 11275/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2853_2919_986_2599_2605.jpg
# image 11276/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2796_360_1209_3312_4152.jpg
# image 11277/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2884_33_1338_3792_3586.jpg
# image 11278/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_1012_1_1.jpg
# image 11279/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_20160308_072831_1921_721.jpg
# image 11280/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_41_40.jpg.jpg
# image 11281/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01673_151_299_1667_2011.jpg
# image 11282/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2901_150_228_2783_3607.jpg
# image 11283/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2914_214_1802_3624_3731.jpg
# image 11284/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_1175_541_641.jpg
# image 11285/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01684_196_795_1339_1768.jpg
# image 11286/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2905_795_159_2896_2675.jpg
# image 11287/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2918_0_0_3840_5760.jpg
# image 11288/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2917_486_1027_3148_3681.jpg
# image 11289/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Volker_DSC01671_561_920_1197_1399.jpg
# image 11290/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/GAPS384_train_0544_541_1.jpg
# image 11291/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_17_1.jpg.jpg
# image 11292/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3098_785_1657_2510_2031.jpg
# image 11293/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A3094_4_1044_3836_4399.jpg
# image 11294/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2831_875_191_2378_2032.jpg
# image 11295/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_51_7.jpg.jpg
# image 11296/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/noncrack_noncrack_concrete_wall_96_23.jpg.jpg
# image 11297/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/CRACK500_IMG_2935_1_969.jpg
# image 11298/11298
# /kaggle/input/crack-segmentation-dataset/crack_segmentation_dataset/masks/Rissbilder_for_Florian_9S6A2814_0_0_3840_5760.jpg

# %%
paths_df.to_csv('path.csv', index=False)

# %%
with open('annotations.json', 'w') as f:
    json.dump(coco_format, f)
